# %%
import pandas as pd

# %%
import statsmodels.api as sm

# %%
import seaborn as sns

# %%
district_df = pd.read_csv("../data/district_case_comps.csv")
crime_df = pd.read_csv("../data/dstrIPC_1.csv")

# %%
crime_df["DISTRICT"] = crime_df["DISTRICT"].str.lower()

# %%
crime_df = crime_df.groupby(["STATE/UT", "DISTRICT"])["TOTAL IPC CRIMES"].mean().reset_index()

# %%
merged_df = district_df.merge(crime_df, left_on="district_name", right_on="DISTRICT", how = "inner")
merged_df
# Out:
#      pc11_state_id  pc11_district_id     state_name district_name  st_share  \
# 0                1                 1  jammu kashmir       kupwara  0.018420
# 1                1                 4  jammu kashmir        kargil  0.298980
# 2                1                 6  jammu kashmir       rajouri  0.128456
# 3                1                 7  jammu kashmir        kathua  0.033276
# 4                1                10  jammu kashmir      srinagar  0.038159
# ..             ...               ...            ...           ...       ...
# 481             33               630     tamil nadu    dharmapuri  0.029023
# 482             33               631     tamil nadu   krishnagiri  0.005238
# 483             33               633     tamil nadu      tiruppur  0.001194
# 484             34               635     puducherry    puducherry  0.000000
# 485             34               637     puducherry      karaikal  0.000000
#
# ...

# %%
merged_df["crime_rate"] = merged_df["TOTAL IPC CRIMES"]/merged_df["tot_p"]

# %%
analysis_df = merged_df[merged_df["crime_rate"] <= .1][
    ["st_share","sc_share", "ptg_share", "inc_5k_plus_share", "ed_prim_share","land_own_share", "crime_rate"]].dropna()

# %%
def norm(col):
    return (col - col.mean())/col.std()

# %%
X = sm.add_constant(analysis_df[["sc_share", "st_share", "ptg_share", "inc_5k_plus_share", "ed_prim_share","land_own_share"]].apply(norm, axis=0))
y = norm(analysis_df["crime_rate"])

# %%
ols = sm.OLS(y, X)

results = ols.fit()

results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             crime_rate   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     3.855
# Date:                Tue, 20 Feb 2024   Prob (F-statistic):           0.000921
# Time:                        23:13:25   Log-Likelihood:                -637.92
# No. Observations:                 458   AIC:                             1290.
# Df Residuals:                     451   BIC:                             1319.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# ...

# %%
sns.scatterplot(data=analysis_df, y="crime_rate", x="sc_share")
# Out:
# <AxesSubplot:xlabel='sc_share', ylabel='crime_rate'>
